# %% [markdown]
# <a href="https://colab.research.google.com/github/RojaCM/DEEP-LEARNING-/blob/main/Keyword%20extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# RAKE

# %%
pip install multi_rake
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 41.4 MB 1.2 MB/s
# ...
#   Created wheel for pycld2: filename=pycld2-0.41-cp37-cp37m-linux_x86_64.whl size=9834259 sha256=9222511fb08f555a89b75cdf9e5539ab0365d5bd7028f033971e6b6911a9ad8f
#   Stored in directory: /root/.cache/pip/wheels/ed/e4/58/ed2e9f43c07d617cc81fe7aff0fc6e42b16c9cf6afe960b614
# Successfully built pycld2
# ...

# %%
title = "ALTIMETRIK DEX"
text = "Altimetrik is a digital business enablement company. We deliver bite-size outcomes as organizations scale digitalization to accelerate revenue growth without disrupting ongoing business operations. Our practitioners and agile engineering teams create solutions that drive transformation and achieve business goals. With offices across the globe and 4,800+ energized practitioners, Altimetrik partners with Fortune 500 and mid-size companies alike to enhance their agility, empowerment, and success."
full_text = title +", "+ text

# %%
from multi_rake import Rake
rake = Rake()
keywords = rake.apply(full_text)
print(keywords[:10])
# Out:
# [('deliver bite-size outcomes', 9.0), ('organizations scale digitalization', 9.0), ('accelerate revenue growth', 9.0), ('achieve business goals', 9.0), ('mid-size companies alike', 9.0), ('800+ energized practitioners', 8.0), ('drive transformation', 4.0), ('altimetrik dex', 3.666666666666667), ('altimetrik partners', 3.666666666666667), ('practitioners', 2.0)]

# %% [markdown]
# KEYBERT

# %%
# !pip install keybert
from keybert import KeyBERT
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 85 kB 4.9 MB/s
# ...
#      |████████████████████████████████| 237 kB 67.8 MB/s
# ...
#      |████████████████████████████████| 51 kB 6.3 MB/s
# ...
#      |████████████████████████████████| 5.3 MB 62.8 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 63.4 MB/s
# ...
#      |████████████████████████████████| 163 kB 84.9 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 65.8 MB/s
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=a03ee4991a20c211e2b9cd1f350e8175d681d5f4d56d774932c2cc335554bd54
#   Stored in directory: /root/.cache/pip/wheels/bf/06/fb/d59c1e5bd1dac7f6cf61ec0036cc3a10ab8fecaa6b2c3d3ee9
# Successfully built sentence-transformers
# ...

# %%
kw_model = KeyBERT(model='all-mpnet-base-v2')
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/363 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.1k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
#ngrams = 2
keywords = kw_model.extract_keywords(full_text, 

                                     keyphrase_ngram_range=(1, 2), 

                                     stop_words='english', 

                                     highlight=True,

                                     top_n=10)

keywords_list= list(dict(keywords).keys())

print(keywords_list)
# Out:
# ALTIMETRIK DEX is digital business company We deliver bite size outcomes as organizations scale digitalization to
# accelerate revenue growth without disrupting ongoing business operations Our practitioners and agile engineering
# teams create solutions that drive transformation and achieve business goals With offices across the globe and 800
# energized practitioners Altimetrik with Fortune 500 and mid size companies alike to enhance their agility
# empowerment and success
# ['altimetrik partners', 'altimetrik digital', 'altimetrik', 'altimetrik dex', 'practitioners altimetrik', 'dex altimetrik', 'enablement company', 'dex', 'digital business', 'digitalization accelerate']

# %%
#ngrams = 2
keywords = kw_model.extract_keywords(full_text, 

                                     keyphrase_ngram_range=(1, 3), 

                                     stop_words='english', 

                                     highlight=True,

                                     top_n=10)

keywords_list= list(dict(keywords).keys())

print(keywords_list)
# Out:
# ALTIMETRIK DEX Altimetrik digital business enablement company We deliver bite size outcomes as organizations scale
# digitalization to accelerate revenue growth without disrupting ongoing business operations Our practitioners and
# agile engineering teams create solutions that drive transformation and achieve business goals With offices across
# the globe and 800 energized practitioners Altimetrik partners Fortune 500 and mid size companies alike to enhance
# their agility empowerment and success
# ['altimetrik digital business', 'altimetrik partners', 'altimetrik dex altimetrik', 'altimetrik digital', 'altimetrik', 'altimetrik dex', 'practitioners altimetrik', 'practitioners altimetrik partners', 'dex altimetrik', 'altimetrik partners fortune']

# %% [markdown]
# TEXT RANK

# %%
# !pip install summa
from summa import keywords
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 54 kB 1.9 MB/s
# ...
#   Created wheel for summa: filename=summa-1.2.0-py3-none-any.whl size=54412 sha256=6e7e2102d98b91f9b37ddf97dff8e59e06ff9ac8a3a882488f192168d2f22686
#   Stored in directory: /root/.cache/pip/wheels/29/64/ac/7b443477588d365ef37ada30d456bdf5f07dc5be9f6324cb6e
# Successfully built summa
# ...

# %%
TR_keywords = keywords.keywords(full_text, scores=True)
print(TR_keywords[0:10])
# Out:
# [('altimetrik', 0.715497005103161), ('practitioners', 0.4769980034021079), ('dex', 0.238499001701054), ('energized', 0.238499001701054), ('partners', 0.2384990017010539), ('business', 0.13003719634549296)]
